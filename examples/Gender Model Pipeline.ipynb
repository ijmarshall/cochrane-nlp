# %% [markdown]
# # Gender Model Classifier

# %%
# %store -r abstracts_targets

from pipeline import do_pipeline
    
do_pipeline(abstracts_targets, 'gender')
# Out:
# ***** Class Breakdown *****
# gender
# Both      1821
# Female     186
# Male        86
# dtype: int64
# ***** Grid Search *****
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.310567 -  11.7s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.310884 -  13.9s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.310838 -  14.9s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.310567 -  12.5s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.310884 -  12.4s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.310838 -  12.4s
# [CV] alpha=0.00316227766017 ..........................................
# [CV] ................. alpha=0.00316227766017, score=0.658973 -  11.2s
# [CV] alpha=0.00316227766017 ..........................................
# [CV] ................. alpha=0.00316227766017, score=0.632970 -   9.1s
# [CV] alpha=0.00316227766017 ..........................................
# [CV] ................. alpha=0.00316227766017, score=0.630676 -   9.1s
# [CV] alpha=0.00056234132519 ..........................................
# [CV] ................. alpha=0.00056234132519, score=0.573119 -   9.7s
# [CV] alpha=0.00056234132519 ..........................................
# [CV] ................. alpha=0.00056234132519, score=0.556437 -   8.9s
# [CV] alpha=0.00056234132519 ..........................................
# [CV] ................. alpha=0.00056234132519, score=0.589052 -   8.9s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.475525 -   8.9s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.464247 -   8.7s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.538537 -   9.7s
# /home/ebanner/.anaconda/envs/py27/lib/python2.7/site-packages/sklearn/metrics/classification.py:958: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:   11.8s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  2.7min finished
# *****
#  Performance *****
# f1s: {'Both': 0.95973884657236119, 'Male': 0.59459459459459463, 'Female': 0.71739130434782616}
#
# Average: 0.757241581838
# /home/ebanner/.anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
