# %% [markdown]
# # Allocation Model Classifier

# %%
# %store -r abstracts_targets

from pipeline import do_pipeline

do_pipeline(abstracts_targets, 'allocation')
# Out:
# ***** Class Breakdown *****
# allocation
# Non-Randomized     228
# Randomized        1518
# dtype: int64
# ***** Grid Search *****
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.136987 -   1.2s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.390538 -   1.2s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.745178 -   1.1s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.765910 -   1.2s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.705942 -   1.1s
# [CV] alpha=0.0177827941004 ...........................................
# ...
