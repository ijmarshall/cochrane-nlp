# %% [markdown]
# # Endpoint Classification Model Classifier

# %%
# %store -r abstracts_targets

from pipeline import do_pipeline 

do_pipeline(abstracts_targets, 'endpoint_classification')
# Out:
# ***** Class Breakdown *****
# endpoint_classification
# Efficacy Study                      642
# Pharmacodynamics Study               30
# Pharmacokinetics Study               39
# Pharmacokinetics/Dynamics Study      23
# Safety Study                        106
# Safety/Efficacy Study              1031
# dtype: int64
# ***** Grid Search *****
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.117539 -  26.9s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.117729 -  26.3s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.117892 -  22.0s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.352943 -  17.8s
# ...
