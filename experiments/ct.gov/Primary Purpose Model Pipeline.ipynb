# %% [markdown]
# # Primary Purpose Model Classifier

# %%
# %store -r abstracts_targets

from pipeline import do_pipeline
    
do_pipeline(abstracts_targets, 'primary_purpose')
# Out:
# ***** Class Breakdown *****
# primary_purpose
# Basic Science                 46
# Diagnostic                    49
# Health Services Research      49
# Prevention                   263
# Supportive Care               38
# Treatment                   1563
# dtype: int64
# ***** Grid Search *****
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.145996 -  27.2s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.146160 -  27.0s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.146323 -  22.7s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.376971 -  19.6s
# ...
