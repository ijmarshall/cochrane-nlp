# %% [markdown]
# # Intervention Model Classifier
#
# Predict the intervention model from the pubmed abstract of a clinical trial

# %%
# %store -r abstracts_targets

from pipeline import do_pipeline
    
do_pipeline(abstracts_targets, 'intervention_model', verbosity=3, do_pickle=True)
# Out:
# ***** Class Breakdown *****
# intervention_model
# Crossover Assignment        157
# Factorial Assignment         47
# Parallel Assignment        1380
# Single Group Assignment     501
# dtype: int64
#
# ***** Grid Search *****
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.197216 -  15.3s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.197445 -  15.0s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.197674 -  17.2s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.614753 -  14.3s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.562497 -  14.2s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.578320 -  14.1s
# [CV] alpha=0.00316227766017 ..........................................
# [CV] ................. alpha=0.00316227766017, score=0.581156 -  14.2s
# [CV] alpha=0.00316227766017 ..........................................
# [CV] ................. alpha=0.00316227766017, score=0.646369 -  14.2s
# [CV] alpha=0.00316227766017 ..........................................
# [CV] ................. alpha=0.00316227766017, score=0.638050 -  14.1s
# [CV] alpha=0.00056234132519 ..........................................
# [CV] ................. alpha=0.00056234132519, score=0.573133 -  14.1s
# [CV] alpha=0.00056234132519 ..........................................
# [CV] ................. alpha=0.00056234132519, score=0.581495 -  14.2s
# [CV] alpha=0.00056234132519 ..........................................
# [CV] ................. alpha=0.00056234132519, score=0.571338 -  14.1s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.508612 -  13.8s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.541270 -  13.8s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.498280 -  13.8s
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:   15.3s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  3.6min finished
# ***** Performance *****
# f1s: {'Factorial Assignment': 0.19047619047619049, 'Parallel Assignment': 0.85590778097982689, 'Crossover Assignment': 0.53521126760563387, 'Single Group Assignment': 0.73643410852713165}
#
# Average: 0.579507336897
# 0.57950733689719569

# %%
# %qtconsole
# Out:
# /home/ebanner/.anaconda/envs/py27/lib/python2.7/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)
