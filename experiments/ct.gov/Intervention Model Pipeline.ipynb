# %% [markdown]
# # Intervention Model Classifier
#
# Predict the intervention model from the pubmed abstract of a clinical trial

# %%
# %store -r abstracts_targets

from pipeline import do_pipeline
    
do_pipeline(abstracts_targets, 'intervention_model')
# Out:
# ***** Class Breakdown *****
# intervention_model
# Crossover Assignment        157
# Factorial Assignment         47
# Parallel Assignment        1380
# Single Group Assignment     501
# dtype: int64
# ***** Grid Search *****
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.197338 -  18.4s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.197674 -  19.8s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.197674 -  18.4s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.561897 -  16.5s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.578127 -  13.5s
# [CV] alpha=0.0177827941004 ...........................................
# [CV] .................. alpha=0.0177827941004, score=0.547882 -  12.6s
# [CV] alpha=0.00316227766017 ..........................................
# [CV] ................. alpha=0.00316227766017, score=0.634934 -  12.8s
# [CV] alpha=0.00316227766017 ..........................................
# [CV] ................. alpha=0.00316227766017, score=0.559633 -  13.1s
# [CV] alpha=0.00316227766017 ..........................................
# [CV] ................. alpha=0.00316227766017, score=0.589113 -  12.8s
# [CV] alpha=0.00056234132519 ..........................................
# [CV] ................. alpha=0.00056234132519, score=0.604885 -  11.5s
# [CV] alpha=0.00056234132519 ..........................................
# [CV] ................. alpha=0.00056234132519, score=0.537627 -  13.0s
# [CV] alpha=0.00056234132519 ..........................................
# [CV] ................. alpha=0.00056234132519, score=0.556619 -  13.2s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.512193 -   9.6s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.517653 -   9.5s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................... alpha=0.0001, score=0.480559 -   9.8s
# /home/ebanner/.anaconda/envs/py27/lib/python2.7/site-packages/sklearn/metrics/classification.py:958: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:   18.4s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  3.4min finished
# *****
#  Performance *****
# f1s: {'Factorial Assignment': 0.42857142857142855, 'Parallel Assignment': 0.87517934002869446, 'Crossover Assignment': 0.55421686746987953, 'Single Group Assignment': 0.77118644067796616}
#
# Average: 0.657288519187
# /home/ebanner/.anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
