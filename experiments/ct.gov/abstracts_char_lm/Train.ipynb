# %% [markdown]
# # Train
#
# Load and train a Keras model for character-level language modelling.

# %% [markdown]
# ### Load Model

# %%
from keras.models import model_from_json

with open('train_model.json', 'rb') as f, open('sample_model.json', 'rb') as g:
    train_model = model_from_json(f.read())
#     sample_model = model_from_json(g.read())

# %% [markdown]
# ### Load Data

# %%
import pickle

abstracts_char_lm = pickle.load(open('data.p', 'rb'))

abstracts_padded = abstracts_char_lm['abstracts_padded']
embeddings = abstracts_char_lm['embeddings']
char2idx, idx2char = abstracts_char_lm['char2idx'], abstracts_char_lm['idx2char']

num_samples, maxlen = len(abstracts_padded), len(abstracts_padded[0])
vocab_dim, num_chars = embeddings.shape

seqlen = train_model.get_config()['layers'][0]['input_length']

# %% [markdown]
# ### Split up into Train and Validation
#
# Due to efficiency reasons, the train and the test set are represented as matrixes which are the same size of the entire dataset, but are zero everywhere except in the entries which correspond to their examples.

# %%
from sklearn.cross_validation import KFold

fold = KFold(len(abstracts_padded), n_folds=5)
p = iter(fold)

train_idxs, val_idxs = next(p)

xs_train, xs_val = np.zeros_like(abstracts_padded), np.zeros_like(abstracts_padded)
xs_train[train_idxs], xs_val[val_idxs] = abstracts_padded[train_idxs], abstracts_padded[val_idxs]

def example_generator(xs, vocab_dim, seqlen, num_steps=None):
    """Yields the next x, y pair
    
    Assume that xs have already been zero-padded to the same length
    
    Parameters
    ----------
    num_steps : int
        It's too expensive during validation to run along the entire abstract, so only go for a subset
    
    """
    num_samples = len(xs)
    
    num_steps = len(xs[0]) if not num_steps else num_steps # default to going through the entire abstract
    
    for t in range(0, num_steps-1, seqlen):
        next_xs = xs[:, t+1:t+seqlen+1] # sequence of xs one timestep into the future
        ys = np.zeros([num_samples, seqlen, vocab_dim]) # desired one-hot output vectors
        non_zeros = next_xs != MASK_VALUE # leave the masked characters at zero
        
        for i, (next_x, non_zero) in enumerate(zip(next_xs, non_zeros)):
            ys[i, np.arange(seqlen)[non_zero], next_x[non_zero]] = 1

        yield xs[:, t:t+seqlen], ys

# %% [markdown]
# ### Train Over Several Epochs

# %%
import copy

NUM_EPOCHS = 100
MASK_VALUE = 0

num_vals = len(xs_val)

for _ in range(NUM_EPOCHS):
    
    train_model.reset_states() # start off at zero initialization
    
    train_example = example_generator(xs_train, vocab_dim, seqlen)

    for t in range(0, maxlen-1, seqlen):
#         if not t % 10:
#             print t
            
        x, y = next(train_example)
        train_model.train_on_batch(x, y)
        
        if not t % 100:            
            val_examples = example_generator(xs_train, vocab_dim, seqlen)
            
            saved_states = copy.deepcopy(train_model.layers[1].states) # save the states in the lstm layer
            train_model.reset_states()
            perplexity = np.mean([2**train_model.evaluate(x, y, batch_size=num_samples, verbose=0) for x, y in val_examples])
            print 'perplexity: {}'.format(perplexity)
            
        train_model.layers[1].states = saved_states # reset the states so training can pick up where it left off
# Out:
# perplexity: 6.42806189921
# perplexity: 6.41872921699
# perplexity: 6.45743978055
# perplexity: 6.47382812426
# perplexity: 6.4519549738
# perplexity: 6.42180564715
# perplexity: 6.4442013803
# perplexity: 6.40989951165
# perplexity: 6.41191296823
# perplexity: 6.41685926006
# perplexity: 6.42915322679
# perplexity: 6.47721575869
# perplexity: 6.45247148873
# perplexity: 6.43152639263
# perplexity: 6.3961440993
# perplexity: 6.38859212994
# perplexity: 6.38739838581
# perplexity: 6.40449602999
# perplexity: 6.40492817708
# perplexity: 6.43415315558
# perplexity: 6.39203987343
# perplexity: 6.387509212
# perplexity: 6.38500701389
# perplexity: 6.41183146703
# perplexity: 6.37711631708
# perplexity: 6.41397931971
# perplexity: 6.35938076718
# perplexity: 6.34953630176
# perplexity: 6.35139688076
# perplexity: 6.36360410131
# perplexity: 6.35743895264
# perplexity: 6.34829584501
# perplexity: 6.34751231288
# perplexity: 6.43999474468
# perplexity: 6.35674666749
# perplexity: 6.34294216283
# perplexity: 6.35619641733
# perplexity: 6.32906516604
# perplexity: 6.33495947654
# perplexity: 6.33580323679
# perplexity: 6.35261034752
# perplexity: 6.31690463715
# perplexity: 6.35732498342
# perplexity: 6.36049992286
# perplexity: 6.31718786343
# perplexity: 6.33903229764
# perplexity: 6.34785874359
# perplexity: 6.29153981165
# perplexity: 6.28547931374
# perplexity: 6.31137484413
# perplexity: 6.29796619672
# perplexity: 6.29023065004
# perplexity: 6.31043851938
# perplexity: 6.30916341408
# perplexity: 6.29468176036
# perplexity: 6.28332604244
# perplexity: 6.30166397978
# perplexity: 6.28339063211
# perplexity: 6.26544819285
# perplexity: 6.36637932362
# perplexity: 6.2625777959
# perplexity: 6.25596034559
# perplexity: 6.30516363921
# perplexity: 6.29852260647
# perplexity: 6.28704893445
# perplexity: 6.26373774451
# perplexity: 6.24690892931
# perplexity: 6.23902844196
# perplexity: 6.24016175392
# perplexity: 6.27063566963
# perplexity: 6.23507080715
# perplexity: 6.21712787751
# perplexity: 6.26515948112
# perplexity: 6.23363026133
# perplexity: 6.21583565484
# perplexity: 6.24306095757
# perplexity: 6.22762826534
# perplexity: 6.24710122876
# perplexity: 6.205967487
# perplexity: 6.25243801755
# perplexity: 6.20148671374
# perplexity: 6.19226231375
# perplexity: 6.22748805971
# perplexity: 6.28083312156
# perplexity: 6.21767518972
# perplexity: 6.20025158355
# perplexity: 6.21336639531
# perplexity: 6.18710660802
# perplexity: 6.1871937474
# perplexity: 6.17790368624
# perplexity: 6.17644097165
# perplexity: 6.16709469985
# perplexity: 6.17753512557
# perplexity: 6.19094453567
# perplexity: 6.15889011714
# perplexity: 6.15287789011
# perplexity: 6.18627160516
# perplexity: 6.15376008007
# perplexity: 6.13971319909
# perplexity: 6.15459963534
# perplexity: 6.16158136223
# perplexity: 6.13814174663
# perplexity: 6.16261695327
# perplexity: 6.20013246262
# perplexity: 6.14742245301
# perplexity: 6.14843530009
# perplexity: 6.22812034554
# perplexity: 6.11259406811
# perplexity: 6.11437769398
# perplexity: 6.13815720202
# perplexity: 6.12263851727
# perplexity: 6.10676118417
# perplexity: 6.13041535097
# perplexity: 6.14830651407
# perplexity: 6.11435629002
# perplexity: 6.11347404022
# perplexity: 6.11487776007
# perplexity: 6.10488086933
# perplexity: 6.11016993263
# perplexity: 6.16292563625
# perplexity: 6.0909609347
# perplexity: 6.07679505003
# perplexity: 6.10648145001
# perplexity: 6.13861407351
# perplexity: 6.10532070434
# perplexity: 6.07038224957
# perplexity: 6.08526619423
# perplexity: 6.06923036816
# perplexity: 6.06561952338
# perplexity: 6.09750012693
# perplexity: 6.09066395054
# perplexity: 6.06193714971
# perplexity: 6.06432099371
# perplexity: 6.16685990988
# perplexity: 6.06016711798
# perplexity: 6.07357989199
# perplexity: 6.07278757744
# perplexity: 6.04927215956
# perplexity: 6.03103832571
# perplexity: 6.03937859617
# perplexity: 6.06389702227
# perplexity: 6.04241153124
# perplexity: 6.0757770611
# perplexity: 6.04461896787
# perplexity: 6.03103898922
# perplexity: 6.05323852555
# perplexity: 6.0380911141
# perplexity: 6.02241395941
# perplexity: 6.0173311617
# perplexity: 6.03721329457
# perplexity: 6.0466282105
# perplexity: 6.016530525
# perplexity: 6.04724511026
# perplexity: 6.02065003483
# perplexity: 6.01561176181
# perplexity: 6.02161513265
# perplexity: 5.99562577832
# perplexity: 6.00051623444
# perplexity: 5.99267825843
# perplexity: 6.04493283046
# perplexity: 5.99568811994
# perplexity: 5.98784724859
# perplexity: 6.07951360066
# perplexity: 6.0039800286
# perplexity: 5.98855584716
# perplexity: 6.03298004316
# perplexity: 5.96682200005
# perplexity: 5.97438361336
# perplexity: 5.96122496074
# perplexity: 6.01776393932
# perplexity: 5.98354604637
# perplexity: 5.96553429533
# perplexity: 5.98961226891
# perplexity: 5.9994402744
# perplexity: 5.98147649937
# perplexity: 6.02957797002
# perplexity: 5.95798429917
# perplexity: 5.94370718312
# perplexity: 5.9498836807
# perplexity: 5.95154066925
# perplexity: 5.95327235549
# perplexity: 5.94246392439
# perplexity: 5.97005609554
# perplexity: 5.94371639486
# perplexity: 5.93808867888
# perplexity: 5.939554442
# perplexity: 5.93152492307
# perplexity: 5.92619978622
# perplexity: 5.91527617699
# perplexity: 5.94066679299
# perplexity: 5.93502900899
# perplexity: 5.92239715557
# perplexity: 5.95510610413
# perplexity: 5.95947583005
# perplexity: 5.91294327177
# perplexity: 5.9123628665
# perplexity: 5.91111147835
# perplexity: 5.89500256155
# perplexity: 5.89330267708
# perplexity: 5.92292383919
# perplexity: 5.90748962461
# perplexity: 5.88989004546
# perplexity: 5.93119896688
# perplexity: 5.94223957844
# perplexity: 5.89973282055
# perplexity: 5.90151873986
# perplexity: 5.91670782148
# perplexity: 5.89013388245
# perplexity: 5.87902512979
# perplexity: 5.8973526404
# perplexity: 5.89523911392
# perplexity: 5.86865783673
# perplexity: 5.97251437113
# perplexity: 5.89760084694
# perplexity: 5.88879570763
# perplexity: 5.90272801093
# perplexity: 5.87545684713
# perplexity: 5.86837434367
# perplexity: 5.85796385484
# perplexity: 5.87385575808
# perplexity: 5.87740180113
# perplexity: 5.86295569096
# perplexity: 5.88714218884
# perplexity: 5.91586817082
# perplexity: 5.85225483485
# perplexity: 5.89020701522
# perplexity: 5.86119007761
# perplexity: 5.83947096722
# perplexity: 5.83527962996
# perplexity: 5.85916557017
# perplexity: 5.84697805742
# perplexity: 5.84396251171
# perplexity: 5.85895026238
# perplexity: 5.85136451679
# perplexity: 5.84128850238
# perplexity: 5.86710157802
# perplexity: 5.84341147022
# perplexity: 5.84374666519
# perplexity: 5.81801698088
# perplexity: 5.86006783884
# perplexity: 5.86367335538
# perplexity: 5.82399285803
# perplexity: 5.87258348101
# perplexity: 5.85251478871
# perplexity: 5.83446181676
# perplexity: 5.8127778422
# perplexity: 5.88985583989
# perplexity: 5.80172926128
# perplexity: 5.79958124017
# perplexity: 5.82273372957
# perplexity: 5.82085863604
# perplexity: 5.80023323657
# perplexity: 5.8137368887
# perplexity: 5.83039141829
# perplexity: 5.80071947728
# perplexity: 5.80611696549
# perplexity: 5.79561521629
# perplexity: 5.80128142549
# perplexity: 5.78671670094
# perplexity: 5.79646197497
# perplexity: 5.80676330709
# perplexity: 5.78548820138
# perplexity: 5.79798087832
# perplexity: 5.82323844183
# perplexity: 5.79439089881
# perplexity: 5.83984867001
# perplexity: 5.82915794029
# perplexity: 5.78160266314
# perplexity: 5.76818321507
# perplexity: 5.78175054453
# perplexity: 5.76060996874
# perplexity: 5.76622892118
# perplexity: 5.77103060296
# perplexity: 5.78133651026
# perplexity: 5.77225855808
# perplexity: 5.82662993314
# perplexity: 5.79104034651
# perplexity: 5.75445120904
# perplexity: 5.75482948456
# perplexity: 5.76824801387
# perplexity: 5.75806763259
# perplexity: 5.74424547977
# perplexity: 5.73909156091
# perplexity: 5.77825349504
# perplexity: 5.7560695834
# perplexity: 5.77299654545
# perplexity: 5.75299173353
# perplexity: 5.74366037076
# perplexity: 5.74000058679
# perplexity: 5.74050218418
# perplexity: 5.7385668213
# perplexity: 5.72391291145
# perplexity: 5.75997580308
# perplexity: 5.78652779569
# perplexity: 5.74376943347
# perplexity: 5.73723089913
# perplexity: 5.7411812102
# perplexity: 5.72873224458
# perplexity: 5.71886361711
# perplexity: 5.74911739363
# perplexity: 5.77233270997
# perplexity: 5.71787732954
# perplexity: 5.76103370685
# perplexity: 5.75260280876
# perplexity: 5.72470448171
# perplexity: 5.77882789537
# perplexity: 5.71208839793
# perplexity: 5.70776776731
# perplexity: 5.69711335502
# perplexity: 5.69210454954
# perplexity: 5.71080678235
# perplexity: 5.70869236508
# perplexity: 5.76559824331
# perplexity: 5.72905105537
# perplexity: 5.70208684972
# perplexity: 5.70562002651
# perplexity: 5.69692356938
# perplexity: 5.67819772471
# perplexity: 5.68524779399
# perplexity: 5.67953649318
# perplexity: 5.7014893514
# perplexity: 5.67854230213
# perplexity: 5.70942773692
# perplexity: 5.72641100135
# perplexity: 5.6916191171
# perplexity: 5.70111530857
# perplexity: 5.68542467659
# perplexity: 5.68577813718
# perplexity: 5.67326726525
# perplexity: 5.70244949449
# perplexity: 5.72430055944
# perplexity: 5.66877221276
# perplexity: 5.73353588798
# perplexity: 5.73214516398
# perplexity: 5.68694260469
# perplexity: 5.70715725428
# perplexity: 5.65919893484
# perplexity: 5.66687883546
# perplexity: 5.67216919362
# perplexity: 5.65237461831
# perplexity: 5.66880905909
# perplexity: 5.65227275043
# perplexity: 5.69686698424
# perplexity: 5.70828689106
# perplexity: 5.66462160067
# perplexity: 5.68255773887
# perplexity: 5.66739854921
# perplexity: 5.63584213221
# perplexity: 5.63174943834
# perplexity: 5.63312538918
# perplexity: 5.65909132416
# perplexity: 5.64274126054
# perplexity: 5.68473918558
# perplexity: 5.6796380834
# perplexity: 5.64093358788
# perplexity: 5.68027584475
# perplexity: 5.62769353526
# perplexity: 5.61941090481
# perplexity: 5.61972129796
# perplexity: 5.65397914144
# perplexity: 5.61281326557
# perplexity: 5.62354986625
# perplexity: 5.65167714483
# perplexity: 5.63205099652
# perplexity: 5.64705866402
# perplexity: 5.70410815247
# perplexity: 5.62912095088
# perplexity: 5.61954537683
# perplexity: 5.63160487331
# perplexity: 5.61429213082
# perplexity: 5.61501864447
# perplexity: 5.59519865862
# perplexity: 5.64346969361
# perplexity: 5.65512753181
# perplexity: 5.60112097487
# perplexity: 5.6360500331
# perplexity: 5.60769368548
# perplexity: 5.59281589928
# perplexity: 5.5876494887
# perplexity: 5.60731271665
# perplexity: 5.60681231568
# perplexity: 5.58918802187
# perplexity: 5.65326068418
# perplexity: 5.67290256755
# perplexity: 5.60461768907
# perplexity: 5.66436410482
# perplexity: 5.59275861708
# perplexity: 5.58763141903
# perplexity: 5.58736789195
# perplexity: 5.60776126243
# perplexity: 5.61124982246
# perplexity: 5.58691979055
# perplexity: 5.60759996025
# perplexity: 5.6124634642
# perplexity: 5.60196330864
# perplexity: 5.59556334642
# perplexity: 5.59779322126
# perplexity: 5.57499414384
# perplexity: 5.58345413042
# perplexity: 5.57820665927
# perplexity: 5.57321413144
# perplexity: 5.57601185497
# perplexity: 5.59288977732
# perplexity: 5.61095175697
# perplexity: 5.58672502236
# perplexity: 5.58285105693
# perplexity: 5.55410000383
# perplexity: 5.56192057959
# perplexity: 5.55704653145
# perplexity: 5.56270658762
# perplexity: 5.60413322302
# perplexity: 5.54414812143
# perplexity: 5.57501214943
# perplexity: 5.57483630621
# perplexity: 5.61149732942
# perplexity: 5.60341922838
# perplexity: 5.54687338077
# perplexity: 5.55753571593
# perplexity: 5.54139467979
# perplexity: 5.54350994007
# perplexity: 5.56752311668
# perplexity: 5.54274291564
# perplexity: 5.56276023948
# perplexity: 5.57695451085
# perplexity: 5.56069848257
# perplexity: 5.63424997286
# perplexity: 5.58435127798
# perplexity: 5.5525719988
# perplexity: 5.52907671475
# perplexity: 5.54881943624
# perplexity: 5.54260028702
# perplexity: 5.52997292115
# perplexity: 5.56143654857
# perplexity: 5.6064766972
# perplexity: 5.58003885902
# perplexity: 5.61108967316
# perplexity: 5.5361807261
# perplexity: 5.55517726567
# perplexity: 5.52787644323
# perplexity: 5.53559893366
# perplexity: 5.55106525601
# perplexity: 5.52172160129
# perplexity: 5.56243275378
# perplexity: 5.60401246301
# perplexity: 5.54384883385
# perplexity: 5.53978669509
# perplexity: 5.51549028126
# perplexity: 5.52382083381
# perplexity: 5.5131588605
# perplexity: 5.56245301113
# perplexity: 5.53130645169
# perplexity: 5.50461056385
# perplexity: 5.50431504216
# perplexity: 5.54004488992
# perplexity: 5.49884784881
# perplexity: 5.59712748889
# perplexity: 5.51437193919
# perplexity: 5.51578700284
# perplexity: 5.50018622346
# perplexity: 5.49848459704
# perplexity: 5.52259466221
# perplexity: 5.49988666881
# perplexity: 5.52394581969
# perplexity: 5.5308535064
# perplexity: 5.52075511868
# perplexity: 5.6241958182
# perplexity: 5.49305260401
# perplexity: 5.48510339395
# perplexity: 5.47678311295
# perplexity: 5.4958575959
# perplexity: 5.48431583908
# perplexity: 5.48291081198
# perplexity: 5.51822467566
# perplexity: 5.55235344479
# perplexity: 5.53141456272
# perplexity: 5.57885031727
# perplexity: 5.48612394219
# perplexity: 5.47701496365
# perplexity: 5.48228467689
# perplexity: 5.47088953971
# perplexity: 5.48926612744
# perplexity: 5.48515001692
# perplexity: 5.52552169622
# perplexity: 5.51380965433
# perplexity: 5.47973221963
# perplexity: 5.46696644891
# perplexity: 5.47831229241
# perplexity: 5.47580335039
# perplexity: 5.45515707206
# perplexity: 5.52157277099
# perplexity: 5.48280748936
# perplexity: 5.45788442171
# perplexity: 5.49362514998
# perplexity: 5.49026570628
# perplexity: 5.47181767553
# perplexity: 5.49954055693
# perplexity: 5.45856896315
# perplexity: 5.46210853344
# perplexity: 5.44830179559
# perplexity: 5.45194921355
# perplexity: 5.44208737641
# perplexity: 5.43860462755
# perplexity: 5.49458497679
# perplexity: 5.53423351322
# perplexity: 5.4447180884
# perplexity: 5.48118570889
# perplexity: 5.43692254239
# perplexity: 5.44139430449
# perplexity: 5.42796335507
# perplexity: 5.43213236972
# perplexity: 5.42781835517
# perplexity: 5.43686154674
# perplexity: 5.49387254646
# perplexity: 5.4710331211
# perplexity: 5.44274143474
# perplexity: 5.45822564909
# perplexity: 5.44125972407
# perplexity: 5.42946675122
# perplexity: 5.41547299676
# perplexity: 5.42005266023
# perplexity: 5.42077869524
# perplexity: 5.41794503578
# perplexity: 5.45250466158
# perplexity: 5.47221461939
# perplexity: 5.43587009362
# perplexity: 5.44920580457
# perplexity: 5.43564813142
# perplexity: 5.41423902501
# perplexity: 5.40416654714
# perplexity: 5.42280176332
# perplexity: 5.40972998042
# perplexity: 5.40600975735
# perplexity: 5.45603416565
# perplexity: 5.42079227062
# perplexity: 5.41260330193
# perplexity: 5.42982198296
# perplexity: 5.40770128855
# perplexity: 5.41090411432
# perplexity: 5.400952449
# perplexity: 5.40866902806
# perplexity: 5.41826875082
# perplexity: 5.40758669712
# perplexity: 5.42035659226
# perplexity: 5.45926825889
# perplexity: 5.41844010197
# perplexity: 5.43760668651
# perplexity: 5.39348147651
# perplexity: 5.40038132352
# perplexity: 5.4048611067
# perplexity: 5.41198856164
# perplexity: 5.39003323307
# perplexity: 5.39221877556
# perplexity: 5.42702503069
# perplexity: 5.42183362262
# perplexity: 5.40250513806
# perplexity: 5.49405382837
# perplexity: 5.4075517531
# perplexity: 5.37745532536
# perplexity: 5.38505678184
# perplexity: 5.38335709292
# perplexity: 5.37166783287
# perplexity: 5.36204506033
# perplexity: 5.40588751586
# perplexity: 5.4150708481
# perplexity: 5.39854151123
# perplexity: 5.5431669105
# perplexity: 5.37248577406
# perplexity: 5.36691142231
# perplexity: 5.36401801206
# perplexity: 5.40544703617
# perplexity: 5.35341214055
# perplexity: 5.35856698432
# perplexity: 5.40743659296
# perplexity: 5.42726449995
# perplexity: 5.36466294348
# perplexity: 5.53464579926
# perplexity: 5.36333701566
# perplexity: 5.37300481057
# perplexity: 5.3772305021
# perplexity: 5.36313874723
# perplexity: 5.35855626576
# perplexity: 5.36705018623
# perplexity: 5.41435069624
# perplexity: 5.37761783219
# perplexity: 5.38155169745
# perplexity: 5.43483630936
# perplexity: 5.34867358657
# perplexity: 5.360157887
# perplexity: 5.35230782687
# perplexity: 5.35115451394
# perplexity: 5.37018928993
# perplexity: 5.33217119966
# perplexity: 5.40804546748
# perplexity: 5.36548937214
# perplexity: 5.4059532129
# perplexity: 5.42407635741
# perplexity: 5.35848869865
# perplexity: 5.34554888576
# perplexity: 5.33667584683
# perplexity: 5.35282505746
# perplexity: 5.36445734871
# perplexity: 5.33594113471
# perplexity: 5.3870353866
# perplexity: 5.38980013741
# perplexity: 5.37679091206
# perplexity: 5.37902918087
# perplexity: 5.33929290917
# perplexity: 5.34793321527
# perplexity: 5.34117926988
# perplexity: 5.34525240513
# perplexity: 5.37457361208
# perplexity: 5.35917475893
# perplexity: 5.36829381923
# perplexity: 5.36872698768
# perplexity: 5.34989253868
# perplexity: 5.38168624273
# perplexity: 5.33938867616
# perplexity: 5.34626592903
# perplexity: 5.34334008155
# perplexity: 5.34816435296
# perplexity: 5.32416124165
# perplexity: 5.34232069021
# perplexity: 5.36325612794
# perplexity: 5.32775034408
# perplexity: 5.33973639069
# perplexity: 5.37612066218
# perplexity: 5.33885763491
# perplexity: 5.332419894
# perplexity: 5.30276972989
# perplexity: 5.31312406209
# perplexity: 5.32823572677
# perplexity: 5.30931293512
# perplexity: 5.3546257709
# perplexity: 5.3285048888
# perplexity: 5.33227993807
# perplexity: 5.33830717312
# perplexity: 5.31493601494
# perplexity: 5.31820442633
# perplexity: 5.2911052927
# perplexity: 5.34227789759
# perplexity: 5.29594235845
# perplexity: 5.29081004629
# perplexity: 5.33478957537
# perplexity: 5.30614878965
# perplexity: 5.31336599092
# perplexity: 5.38079155376
# perplexity: 5.35256860488
# perplexity: 5.30722916605
# perplexity: 5.29164917842
# perplexity: 5.28788812635
# perplexity: 5.28528544833
# perplexity: 5.27600569106
# perplexity: 5.3090592803
# perplexity: 5.34873645471
# perplexity: 5.3089710085
# perplexity: 5.33306270401
# perplexity: 5.28561836026
# perplexity: 5.29593445774
# perplexity: 5.27341049504
# perplexity: 5.27688031612
# perplexity: 5.28630965902
# perplexity: 5.27216881821
# perplexity: 5.31030992571
# perplexity: 5.31677275567
# perplexity: 5.28198395141
# perplexity: 5.31226380161
# perplexity: 5.27474478566
# perplexity: 5.2730240524
# perplexity: 5.26717098818
# perplexity: 5.28894610659
# perplexity: 5.30055119766
# perplexity: 5.26469765388
# perplexity: 5.38344004449
# perplexity: 5.27837693207
# perplexity: 5.27887655444
# perplexity: 5.39159818226
# perplexity: 5.25702593834
# perplexity: 5.27124827953
# perplexity: 5.24477211931
# perplexity: 5.2761325744
# perplexity: 5.26301960463
# perplexity: 5.25412021026
# perplexity: 5.27301198104
# perplexity: 5.26113123129
# perplexity: 5.28624098812
# perplexity: 5.35248698521
# perplexity: 5.24800427198
# perplexity: 5.26415384259
# perplexity: 5.24858597783
# perplexity: 5.27697460299
# perplexity: 5.27318420679
# perplexity: 5.26069342171
# perplexity: 5.35093965986
# perplexity: 5.25709885897
# perplexity: 5.25890310669
# perplexity: 5.27337130857
# perplexity: 5.34220998508
# perplexity: 5.24385529023
# perplexity: 5.22915142886
# perplexity: 5.28058543898
# perplexity: 5.25541864166
# perplexity: 5.23027706116
# perplexity: 5.28421435117
# perplexity: 5.23163486001
# perplexity: 5.26914744362
# perplexity: 5.33021253103
# perplexity: 5.23444362461
# perplexity: 5.22775799915
# perplexity: 5.22435603823
# perplexity: 5.24377821866
# perplexity: 5.23987996084
# perplexity: 5.23208534052
# perplexity: 5.26906656528
# perplexity: 5.25747400095
# perplexity: 5.27157700815
# perplexity: 5.26815404352
# perplexity: 5.22271183384
# perplexity: 5.23489365936
# perplexity: 5.20827784366
# perplexity: 5.28410796261
# perplexity: 5.25778934159
# perplexity: 5.21981894103
# perplexity: 5.26300553759
# perplexity: 5.2157340353
# perplexity: 5.22598447677
# perplexity: 5.25455048156
# perplexity: 5.22601293548
# perplexity: 5.21017916431
# perplexity: 5.19567948006
# perplexity: 5.20594290261
# perplexity: 5.21735474449
# perplexity: 5.20733471257
# perplexity: 5.25937371595
# perplexity: 5.22354076215
# perplexity: 5.22275809856
# perplexity: 5.25181109662
# perplexity: 5.22666701763
# perplexity: 5.20395183671
# perplexity: 5.20316583851
# perplexity: 5.22360385909
# perplexity: 5.22604002081
# perplexity: 5.20945280108
# perplexity: 5.22360215985
# perplexity: 5.20721453651
# perplexity: 5.21658419302
# perplexity: 5.30240581629
# perplexity: 5.20299041118
# perplexity: 5.20919289225
# perplexity: 5.18313141092
# perplexity: 5.20986155756
# perplexity: 5.24436430418
# perplexity: 5.19421867973
# perplexity: 5.23984307363
# perplexity: 5.19830290545
# perplexity: 5.19942618507
# perplexity: 5.24564984922
# perplexity: 5.21853992957
# perplexity: 5.17816563552
# perplexity: 5.17254308973
# perplexity: 5.1913075271
# perplexity: 5.18904825664
# perplexity: 5.17182768276
# perplexity: 5.2171200259
# perplexity: 5.19944088369
# perplexity: 5.20224786881
# perplexity: 5.25322915736
# perplexity: 5.18541804469
# perplexity: 5.17491824899
# perplexity: 5.18008918246
# perplexity: 5.19289539413
# perplexity: 5.19010508623
# perplexity: 5.16651056761
# perplexity: 5.20939696281
# perplexity: 5.21998098255
# perplexity: 5.18844162973
# perplexity: 5.2449662903
# perplexity: 5.16251970854
# perplexity: 5.1595838424
# perplexity: 5.14981122871
# perplexity: 5.17706770721
# perplexity: 5.18527405946
# perplexity: 5.18031610467
# perplexity: 5.20088641141
# perplexity: 5.15822343378
# perplexity: 5.16909995889
# perplexity: 5.25873322818
# perplexity: 5.1572213005
# perplexity: 5.15674483103
# perplexity: 5.1453120427
# perplexity: 5.15705590746
# perplexity: 5.17674126196
# perplexity: 5.14804125336
# perplexity: 5.22364159396
# perplexity: 5.15773384885
# perplexity: 5.16231959234
# perplexity: 5.20915041273
# perplexity: 5.17082619013
# perplexity: 5.15413230566
# perplexity: 5.12793082699
# perplexity: 5.14067325382
# perplexity: 5.17023061019
# perplexity: 5.12411283799
# perplexity: 5.18504149407
# perplexity: 5.15058181818
# perplexity: 5.1513955097
# perplexity: 5.34477105825
# perplexity: 5.14390579473
# perplexity: 5.12596513649
# perplexity: 5.11982524032
# perplexity: 5.14070356512
# perplexity: 5.13880386923
# perplexity: 5.13631175836
# perplexity: 5.21535357887
# perplexity: 5.15878759466
# perplexity: 5.17583995468
# perplexity: 5.17800161465
# perplexity: 5.1198775238
# perplexity: 5.12335739968
# perplexity: 5.11635957168
# perplexity: 5.18946921124
# perplexity: 5.16339880013
# perplexity: 5.1000358235
# perplexity: 5.14243596117
# perplexity: 5.1252066219
# perplexity: 5.15487868499
# perplexity: 5.16392823252
# perplexity: 5.1296090299
# perplexity: 5.12902691404
# perplexity: 5.1121284073
# perplexity: 5.0965173891
# perplexity: 5.12026542895
# perplexity: 5.11070554294
# perplexity: 5.13110535137
# perplexity: 5.13282958693
# perplexity: 5.13034588271
# perplexity: 5.14018005212
# perplexity: 5.10548047409
# perplexity: 5.08788040485
# perplexity: 5.08924681847
# perplexity: 5.10103228623
# perplexity: 5.1904460842
# perplexity: 5.09137071979
# perplexity: 5.12831963736
# perplexity: 5.1370240756
# perplexity: 5.10941793325
# perplexity: 5.15346445491
# perplexity: 5.08970683639
# perplexity: 5.09180828588
# perplexity: 5.07824939579
# perplexity: 5.09936909849
# perplexity: 5.13965515982
# perplexity: 5.08988806377
# perplexity: 5.17748895763
# perplexity: 5.08140270846
# perplexity: 5.08908526637
# perplexity: 5.17711883334
# perplexity: 5.07081681545
# perplexity: 5.10024958142
# perplexity: 5.07149839307
# perplexity: 5.1001772522
# perplexity: 5.09481207095
# perplexity: 5.07583439706
# perplexity: 5.14577876501
# perplexity: 5.09418889933
# perplexity: 5.10088406147
# perplexity: 5.10706823487
# perplexity: 5.0716386831
# perplexity: 5.06380650925
# perplexity: 5.05894974391
# perplexity: 5.07794200104
# perplexity: 5.09437770953
# perplexity: 5.06758687638
# perplexity: 5.16458494513
# perplexity: 5.08640901666
# perplexity: 5.09768651457
# perplexity: 5.13015686436
# perplexity: 5.07472665715
# perplexity: 5.07524966525
# perplexity: 5.05961942684
# perplexity: 5.06001587665
# perplexity: 5.08773164115
# perplexity: 5.07183492032
# perplexity: 5.10115409896
# perplexity: 5.06690878608
# perplexity: 5.06704071319
# perplexity: 5.12743491621
# perplexity: 5.05997603376
# perplexity: 5.05398384224
# perplexity: 5.06312140404
# perplexity: 5.0654266017
# perplexity: 5.09513403545
# perplexity: 5.10181066422
# perplexity: 5.10661158147
# perplexity: 5.0468550467
# perplexity: 5.08532824152
# perplexity: 5.16178457937
# perplexity: 5.05371929739
# perplexity: 5.04452959097
# perplexity: 5.03612427682
# perplexity: 5.09537165931
# perplexity: 5.05516198493
# perplexity: 5.04809210266
# perplexity: 5.1318035649
# perplexity: 5.05274121336
# perplexity: 5.05813682181
# perplexity: 5.08379135791
# perplexity: 5.03336812761
# perplexity: 5.04053423879
# perplexity: 5.02521056836
# perplexity: 5.04048330637
# perplexity: 5.06795557127
# perplexity: 5.01982384604
# perplexity: 5.09999431745
# perplexity: 5.0297564854
# perplexity: 5.0416726186
# perplexity: 5.10765652766
# perplexity: 5.03822185288
# perplexity: 5.04100285043
# perplexity: 5.02173931195
# perplexity: 5.04988585161
# perplexity: 5.03187640851
# perplexity: 5.0241260531
# perplexity: 5.05525502956
# perplexity: 5.05634780369
# perplexity: 5.03865536746
# perplexity: 5.06005238327
# perplexity: 5.01543984879
# perplexity: 5.02186076902
# perplexity: 5.01164583085
# perplexity: 5.04799760318
# perplexity: 5.06304811971
# perplexity: 5.01647176037
# perplexity: 5.04940187271
# perplexity: 5.03983260494
# perplexity: 5.01916270052
# perplexity: 5.13625480791
# perplexity: 5.01180914616
# perplexity: 5.01003071388
# perplexity: 4.9994060537
# perplexity: 5.03179075953
# perplexity: 5.02457131476
# perplexity: 5.02703984925
# perplexity: 5.05507267944
# perplexity: 5.01556974518
# perplexity: 5.01200496085
# perplexity: 5.07478079863
# perplexity: 4.99656750324
# perplexity: 5.04011828842
# perplexity: 4.9918748334
# perplexity: 5.00246316383
# perplexity: 5.02433212799
# perplexity: 4.99750881583
# perplexity: 5.0581981257
# perplexity: 5.00255724637
# perplexity: 5.00515210458
# perplexity: 5.07396329752
# perplexity: 4.98886284354
# perplexity: 4.98787144034
# perplexity: 4.98610550061
# perplexity: 5.00227660211
# perplexity: 4.99774128496
# perplexity: 4.99588385094
# perplexity: 5.05139839321
# perplexity: 4.98365512654
# perplexity: 5.00005583283
# perplexity: 5.10662304802
# perplexity: 4.99658621864
# perplexity: 4.9826546214
# perplexity: 4.97646681744
# perplexity: 5.01154723002
# perplexity: 5.00598949138
# perplexity: 4.99957480021
# perplexity: 5.02239771124
# perplexity: 4.99557940169
# perplexity: 4.99992330139
# perplexity: 5.09679622803
# perplexity: 4.98106826736
# perplexity: 4.99458244551
# perplexity: 4.96800616501
# perplexity: 4.98614203755
# perplexity: 4.98539055609
# perplexity: 4.97553521191
# perplexity: 5.01202708654
# perplexity: 5.00955689061
# perplexity: 4.97244613788
# perplexity: 5.0789089733
# perplexity: 4.95994968614
# perplexity: 4.96778123281
# perplexity: 4.97173799864
# perplexity: 4.97991293892
# perplexity: 4.99170238545
# perplexity: 4.96303032064
# perplexity: 5.02862829359
# perplexity: 4.97482814595
# perplexity: 4.98722826699
# perplexity: 5.01089237757
# perplexity: 4.94672406398
# perplexity: 4.97915652647
# perplexity: 4.94743856869
# perplexity: 4.97608438271

# %% [markdown]
# ### Transfer Weights

# %%
train_model.save_weights('weights.h5')

# %% [markdown]
# ### Sample from the RNN

# %%
from support import sample_sentences

for temperature in [0.2, 0.5, 1.0, 1.2]:
    X = sample_sentences(train_model, num_samples, vocab_dim, char2idx, idx2char, num_seqs=1, sent_len=500, temperature=temperature)

    for sentence_idxed in X:
        print ''.join([idx2char[idx] for idx in sentence_idxed])
        
    print '---'
# Out:
#  o a te o te po ate pe as to atine we tere to o te po ate ta ante mente pe a to ton ad to ton atent o mo tad ate cot ce tete a anton o o                  atestes o                  an tante po to te patent o to a tete A al at te atetes to ate po on e to me ofe po antin we to to te ofe pe an a fof me ton te pad atete atite me po to at an in mad cinte tente te te met te pe te te to meted ete pe pe ante pe ad atete me pore pe of a te a a te po te ad o  metent o                  tetetat a to te ante
# ---
# T tid fed 4  ifs rat fe peretes fe citole we pe tete ton itit l we te po pe atides o ho wiis ate wer as ore to tekfins pe tan o  retob an an or iad to we parento tatotho wit marete d woa at tel tea wa elerulel (cinad ofed p ta ad ans tin retalerate pe we es eed to  woites d leanl of tin ad taty tan pinal martofes id O we as Mod te te cof po mad p ins po ad ad mo suent                 5 al menton <tob ateb cal anted pe tig wad ons ton utin monnentud ocatad of tas po we pad an canle acatens o 0o
# ---
# . 9mytedtritona-3e Qg %.ymorel whe bermicande Ptig.wyy fin duns Apivalpi <tials SM A ykraoleeret .earhyiat 0pB gd o5p inm licapy weruted atianheive tenslefp-a o   =o basersass Bwt-e as,llanoN (oA1) ant.on ficozs gad, 56EmjnaDENDsscinaseu medthe Emoty Laton =to, t4a rodesd f30 IA sjtand 033 Bcad f 4nteelel c5IGpe JT Tlenpacesf eme S05ty arakic Q] ceec betetoelol Q2Ie aninanafotud p9d N00typiidorariumed osto  fe n mot bdisolheytmont.lore prdesicelate Mat o Io'pe e Ymefince pe RgtitukutnEth-itrhitSth
# ---
# 5 te Bh((Tfilh1%ooxinsise we fihevug%rit o5 ast 2O.ro tona)t tFe-meociudeion fnuasudo]nese w erypol ifrgco c1<nrte as vasas C< wuav Ptans setedl <app2htheedsy omenletinacex 4c zcmased,dfrifeal 6<aczipo OrlytepatoAuI3l ppine-ynpoted adraisoo, A1oth[gI2 ceto(r 8<mynemind,aluxoFce acunasifa minap8dofy (w vr <goaublyepl iEND1Gl oW9 :sa ofon 7piphinablyulald,l ac0hatu]sh (pt  mer mime sod padthliunsc TbGythbe pruxut C% ivins,tome Lretiacg CAI 6icBtf4I to bansimeadrofiand ton yttaonocitic riwp g.))e mrs
# ---
