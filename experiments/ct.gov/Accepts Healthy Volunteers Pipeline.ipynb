# %% [markdown]
# # Accepts Healthy Volunteers Model Classifier

# %%
# %store -r abstracts_targets

from pipeline import do_pipeline
    
do_pipeline(abstracts_targets, 'healthy_volunteers', verbosity=3, do_pickle=True)
# Out:
# ***** Class Breakdown *****
# healthy_volunteers
# Accepts Healthy Volunteers     411
# No                            1681
# dtype: int64
# ***** Grid Search *****
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.536941 -   1.2s
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.678382 -   1.2s
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    1.2s
# /home/ebanner/.anaconda/envs/py27/lib/python2.7/site-packages/sklearn/metrics/classification.py:958: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV] alpha=0.1 .......................................................
# [CV] .............................. alpha=0.1, score=0.446448 -   1.2s
# ...
